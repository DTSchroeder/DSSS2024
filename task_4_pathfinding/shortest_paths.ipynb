# %% [markdown]
# # Shortest Path
#  NetworkX's shortest paths are documented [here](https://networkx.org/documentation/stable/reference/algorithms/shortest_paths.html). In the box below, you see the imports, including our Neo4j utility, which is a singleton that includes the necessary functions we implemented in the previous tutorials.

# %%
import sys
import os
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Define the directory containing neo4j_utils.py (assuming test.ipynb is in task_1 folder)
module_path = os.path.abspath(os.path.join(os.path.dirname("__file__"), '..', 'utils'))

# Check if the path is already in sys.path and add it if not
if module_path not in sys.path:
    print(f"Adding {module_path} to sys.path")
    sys.path.append(module_path)

import neo4j_utils as neo4j

# Get the instance of the Neo4jConnection
db = neo4j.Neo4jConnection.get_instance()

# Verify the connection
if db.verify_connection():
    print("Connection to Neo4j is successful!")
else:
    print("Connection to Neo4j failed!")

# close the connection
db.close()
# Out:
# Adding /Users/ramadanomar/projects/dsis-2024/Graph_Data_Analytics/utils to sys.path
# Connection to Neo4j is successful!

# %% [markdown]
# # All Pairs Shortest Path in the Largest Community

# %%
# Get the instance of Neo4jConnection
db = neo4j.Neo4jConnection.get_instance()

# Load data into NetworkX
graph = db.load_data_into_networkx()

# Extract the largest community subgraph
largest_community_subgraph = db.subgraph_largest_community()

# Compute all pairs shortest path lengths
shortest_paths = dict(nx.all_pairs_shortest_path_length(largest_community_subgraph))

# Print or process the shortest paths as needed
for node, paths in shortest_paths.items():
    print(f"Shortest paths from node {node}:")
    for target, length in paths.items():
        print(f"  to {target}: {length} steps")

# Close the Neo4j connection when done
db.close()
# Out:
# Shortest paths from node Marya-Seaworth:
#   to Marya-Seaworth: 0 steps
#   to Allard-Seaworth: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Davos-Seaworth: 2 steps
#   to Alester-Florent: 2 steps
#   to Axell-Florent: 2 steps
#   to Cortnay-Penrose: 2 steps
#   to Cressen: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Melisandre: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Patchface: 2 steps
#   to Pylos: 2 steps
#   to Salladhor-Saan: 2 steps
#   to Selyse-Florent: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Alliser-Thorne: 2 steps
#   to Azor-Ahai: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Donal-Noye: 2 steps
#   to Edric-Storm: 2 steps
#   to Janos-Slynt: 2 steps
#   to Jon-Snow: 2 steps
#   to Khorane-Sathmantes: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Clydas: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Val: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Dalla: 2 steps
#   to Sigorn: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Mance-Rayder: 2 steps
#   to Clayton-Suggs: 2 steps
#   to Godry-Farring: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Corliss-Penny: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Imry-Florent: 3 steps
#   to Matthos-Seaworth: 3 steps
#   to Andrew-Estermont: 3 steps
#   to Guncer-Sunglass: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Bartimus: 3 steps
#   to Sybell-Spicer: 3 steps
#   to Garth-(Wolfs-Den): 3 steps
#   to Godric-Borrell: 3 steps
#   to Leona-Woolfield: 3 steps
#   to Gilly: 3 steps
#   to Rattleshirt: 3 steps
#   to Ygritte: 3 steps
#   to Alys-Karstark: 3 steps
#   to Hobb: 3 steps
#   to Joramun: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Satin: 3 steps
#   to Wun-Weg-Wun-Dar-Wun: 3 steps
#   to Benethon-Scales: 3 steps
#   to Narbert-Grandison: 3 steps
#   to Brus-Buckler: 3 steps
#   to Malegorn: 3 steps
#   to Patrek-of-Kings-Mountain: 3 steps
#   to Chett: 3 steps
#   to Jeor-Mormont: 3 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Denys-Mallister: 3 steps
#   to Eddison-Tollett: 3 steps
#   to Grenn: 3 steps
#   to Owen: 3 steps
#   to Pypar: 3 steps
#   to Wynton-Stout: 3 steps
#   to Alleras: 3 steps
#   to Dareon: 3 steps
#   to Halder: 3 steps
#   to Rast: 3 steps
#   to Qhorin-Halfhand: 3 steps
#   to Othell-Yarwyck: 3 steps
#   to Mag-Mar-Tun-Doh-Weg: 3 steps
#   to Emmett: 3 steps
#   to Albett: 3 steps
#   to Dywen: 3 steps
#   to Jaremy-Rykker: 3 steps
#   to Matthar: 3 steps
#   to Othor: 3 steps
#   to Todder: 3 steps
#   to Craster: 3 steps
#   to Dalbridge: 3 steps
#   to Ebben: 3 steps
#   to Hake: 3 steps
#   to Jarman-Buckwell: 3 steps
#   to Lark: 3 steps
#   to Ottyn-Wythers: 3 steps
#   to Stonesnake: 3 steps
#   to Thoren-Smallwood: 3 steps
#   to Arson: 3 steps
#   to Big-Boil: 3 steps
#   to Dick-Follard: 3 steps
#   to Errok: 3 steps
#   to Gendel: 3 steps
#   to Gorne: 3 steps
#   to Grigg: 3 steps
#   to Hareth-(Moles-Town): 3 steps
#   to Harma: 3 steps
#   to Jarl: 3 steps
#   to Kegs: 3 steps
#   to Mully: 3 steps
#   to Orell: 3 steps
#   to Ryk: 3 steps
#   to Spare-Boot: 3 steps
#   to Styr: 3 steps
#   to Tormund: 3 steps
#   to Varamyr: 3 steps
#   to Zei: 3 steps
#   to Wick-Whittlestick: 3 steps
#   to Leathers: 3 steps
#   to Rory: 3 steps
#   to Soren-Shieldbreaker: 3 steps
#   to Tom-Barleycorn: 3 steps
#   to Toregg: 3 steps
#   to Ulmer: 3 steps
#   to Weeper: 3 steps
#   to Cellador: 3 steps
#   to Brandon-Norrey: 3 steps
#   to Hop-Robin: 3 steps
#   to Fulk: 3 steps
#   to Gerrick-Kingsblood: 3 steps
#   to Bannen: 3 steps
#   to Bedwyck: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Small-Paul: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Hother-Umber: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Gerald-Gower: 4 steps
#   to Gawen-Westerling: 4 steps
#   to Bael-the-Bard: 4 steps
#   to Arron: 4 steps
#   to Emrick: 4 steps
#   to Blane: 4 steps
#   to Watt: 4 steps
#   to Armen: 4 steps
#   to Mollander: 4 steps
#   to Pate-(novice): 4 steps
#   to Roone: 4 steps
#   to Lanna-(Happy-Port): 4 steps
#   to Ragwyle: 4 steps
#   to Jafer-Flowers: 4 steps
#   to Byam-Flint: 4 steps
#   to Softfoot: 4 steps
#   to Mallador-Locke: 4 steps
#   to Munda: 4 steps
#   to Dryn: 4 steps
#   to Bump: 4 steps
#   to Haggon: 4 steps
#   to Thistle: 4 steps
#   to Torghen-Flint: 4 steps
#   to Raymun-Redbeard: 4 steps
#   to Walgrave: 5 steps
#   to Quill: 5 steps
#   to Rosey: 5 steps
#   to Gormon-Tyrell: 6 steps
# Shortest paths from node Quill:
#   to Quill: 0 steps
#   to Pate-(novice): 1 steps
#   to Alleras: 2 steps
#   to Armen: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Mollander: 2 steps
#   to Walgrave: 2 steps
#   to Rosey: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 3 steps
#   to Samwell-Tarly: 3 steps
#   to Marwyn: 3 steps
#   to Roone: 3 steps
#   to Gormon-Tyrell: 3 steps
#   to Alliser-Thorne: 4 steps
#   to Bowen-Marsh: 4 steps
#   to Chett: 4 steps
#   to Clydas: 4 steps
#   to Jeor-Mormont: 4 steps
#   to Jon-Snow: 4 steps
#   to Aegon-V-Targaryen: 4 steps
#   to Daeron-II-Targaryen: 4 steps
#   to Maekar-I-Targaryen: 4 steps
#   to Cotter-Pyke: 4 steps
#   to Denys-Mallister: 4 steps
#   to Donal-Noye: 4 steps
#   to Eddison-Tollett: 4 steps
#   to Grenn: 4 steps
#   to Hobb: 4 steps
#   to Janos-Slynt: 4 steps
#   to Mance-Rayder: 4 steps
#   to Owen: 4 steps
#   to Pypar: 4 steps
#   to Stannis-Baratheon: 4 steps
#   to Wynton-Stout: 4 steps
#   to Dareon: 4 steps
#   to Gilly: 4 steps
#   to Halder: 4 steps
#   to Rast: 4 steps
#   to Craster: 4 steps
#   to Ottyn-Wythers: 4 steps
#   to Bannen: 4 steps
#   to Bedwyck: 4 steps
#   to Clubfoot-Karl: 4 steps
#   to Dirk: 4 steps
#   to Dywen: 4 steps
#   to Lark: 4 steps
#   to Melisandre: 4 steps
#   to Qhorin-Halfhand: 4 steps
#   to Small-Paul: 4 steps
#   to Xhondo: 4 steps
#   to Theobald: 4 steps
#   to Kojja-Mo: 4 steps
#   to Quhuru-Mo: 4 steps
#   to Othell-Yarwyck: 5 steps
#   to Satin: 5 steps
#   to Cellador: 5 steps
#   to Tormund: 5 steps
#   to Wick-Whittlestick: 5 steps
#   to Mully: 5 steps
#   to Jaremy-Rykker: 5 steps
#   to Jarman-Buckwell: 5 steps
#   to Thoren-Smallwood: 5 steps
#   to Blane: 5 steps
#   to Albett: 5 steps
#   to Matthar: 5 steps
#   to Othor: 5 steps
#   to Todder: 5 steps
#   to Dalbridge: 5 steps
#   to Ebben: 5 steps
#   to Hake: 5 steps
#   to Rattleshirt: 5 steps
#   to Stonesnake: 5 steps
#   to Ygritte: 5 steps
#   to Arson: 5 steps
#   to Big-Boil: 5 steps
#   to Dalla: 5 steps
#   to Dick-Follard: 5 steps
#   to Errok: 5 steps
#   to Gendel: 5 steps
#   to Gorne: 5 steps
#   to Grigg: 5 steps
#   to Hareth-(Moles-Town): 5 steps
#   to Harma: 5 steps
#   to Jarl: 5 steps
#   to Kegs: 5 steps
#   to Mag-Mar-Tun-Doh-Weg: 5 steps
#   to Orell: 5 steps
#   to Ryk: 5 steps
#   to Spare-Boot: 5 steps
#   to Styr: 5 steps
#   to Val: 5 steps
#   to Varamyr: 5 steps
#   to Zei: 5 steps
#   to Sigorn: 5 steps
#   to Tycho-Nestoris: 5 steps
#   to Selyse-Florent: 5 steps
#   to Shireen-Baratheon: 5 steps
#   to Narbert-Grandison: 5 steps
#   to Malegorn: 5 steps
#   to Leathers: 5 steps
#   to Rory: 5 steps
#   to Patrek-of-Kings-Mountain: 5 steps
#   to Soren-Shieldbreaker: 5 steps
#   to Tom-Barleycorn: 5 steps
#   to Toregg: 5 steps
#   to Ulmer: 5 steps
#   to Weeper: 5 steps
#   to Wun-Weg-Wun-Dar-Wun: 5 steps
#   to Alys-Karstark: 5 steps
#   to Godry-Farring: 5 steps
#   to Axell-Florent: 5 steps
#   to Brandon-Norrey: 5 steps
#   to Devan-Seaworth: 5 steps
#   to Emmett: 5 steps
#   to Hop-Robin: 5 steps
#   to Fulk: 5 steps
#   to Gerrick-Kingsblood: 5 steps
#   to Watt: 5 steps
#   to Joramun: 5 steps
#   to Alester-Florent: 5 steps
#   to Allard-Seaworth: 5 steps
#   to Cortnay-Penrose: 5 steps
#   to Cressen: 5 steps
#   to Davos-Seaworth: 5 steps
#   to Monford-Velaryon: 5 steps
#   to Patchface: 5 steps
#   to Pylos: 5 steps
#   to Salladhor-Saan: 5 steps
#   to Azor-Ahai: 5 steps
#   to Edric-Storm: 5 steps
#   to Khorane-Sathmantes: 5 steps
#   to Wyman-Manderly: 5 steps
#   to Theomore: 5 steps
#   to William-Foxglove: 5 steps
#   to Arnolf-Karstark: 5 steps
#   to Mors-Umber: 5 steps
#   to Clayton-Suggs: 5 steps
#   to Corliss-Penny: 5 steps
#   to Marlon-Manderly: 5 steps
#   to Lyanna-Mormont: 5 steps
#   to Marya-Seaworth: 5 steps
#   to Roose-Ryswell: 5 steps
#   to Lanna-(Happy-Port): 5 steps
#   to Byam-Flint: 5 steps
#   to Softfoot: 5 steps
#   to Guncer-Sunglass: 5 steps
#   to Ragwyle: 5 steps
#   to Arron: 6 steps
#   to Emrick: 6 steps
#   to Munda: 6 steps
#   to Dryn: 6 steps
#   to Jafer-Flowers: 6 steps
#   to Mallador-Locke: 6 steps
#   to Bael-the-Bard: 6 steps
#   to Bump: 6 steps
#   to Haggon: 6 steps
#   to Thistle: 6 steps
#   to Benethon-Scales: 6 steps
#   to Brus-Buckler: 6 steps
#   to Daeron-I-Targaryen: 6 steps
#   to Lamprey: 6 steps
#   to Porridge: 6 steps
#   to Torghen-Flint: 6 steps
#   to Raymun-Redbeard: 6 steps
#   to Imry-Florent: 6 steps
#   to Matthos-Seaworth: 6 steps
#   to Andrew-Estermont: 6 steps
#   to Bartimus: 6 steps
#   to Sybell-Spicer: 6 steps
#   to Garth-(Wolfs-Den): 6 steps
#   to Godric-Borrell: 6 steps
#   to Leona-Woolfield: 6 steps
#   to Ardrian-Celtigar: 6 steps
#   to Hother-Umber: 6 steps
#   to Arthor-Karstark: 6 steps
#   to Gerald-Gower: 7 steps
#   to Gawen-Westerling: 7 steps
# Shortest paths from node Grenn:
#   to Grenn: 0 steps
#   to Alliser-Thorne: 1 steps
#   to Halder: 1 steps
#   to Jeor-Mormont: 1 steps
#   to Jon-Snow: 1 steps
#   to Pypar: 1 steps
#   to Samwell-Tarly: 1 steps
#   to Todder: 1 steps
#   to Dywen: 1 steps
#   to Aemon-Targaryen-(Maester-Aemon): 1 steps
#   to Bedwyck: 1 steps
#   to Craster: 1 steps
#   to Eddison-Tollett: 1 steps
#   to Kegs: 1 steps
#   to Owen: 1 steps
#   to Small-Paul: 1 steps
#   to Bowen-Marsh: 2 steps
#   to Rast: 2 steps
#   to Janos-Slynt: 2 steps
#   to Mance-Rayder: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Stannis-Baratheon: 2 steps
#   to Albett: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Blane: 2 steps
#   to Chett: 2 steps
#   to Donal-Noye: 2 steps
#   to Lark: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Dareon: 2 steps
#   to Hobb: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Hake: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Clydas: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gilly: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Melisandre: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Ryk: 2 steps
#   to Satin: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Godry-Farring: 2 steps
#   to Axell-Florent: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Denys-Mallister: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Bannen: 2 steps
#   to Clubfoot-Karl: 2 steps
#   to Dirk: 2 steps
#   to Alleras: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Aegon-V-Targaryen: 2 steps
#   to Daeron-II-Targaryen: 2 steps
#   to Maekar-I-Targaryen: 2 steps
#   to Wynton-Stout: 2 steps
#   to Byam-Flint: 2 steps
#   to Watt: 2 steps
#   to Joramun: 3 steps
#   to Ragwyle: 3 steps
#   to Alester-Florent: 3 steps
#   to Allard-Seaworth: 3 steps
#   to Cortnay-Penrose: 3 steps
#   to Cressen: 3 steps
#   to Davos-Seaworth: 3 steps
#   to Monford-Velaryon: 3 steps
#   to Patchface: 3 steps
#   to Pylos: 3 steps
#   to Salladhor-Saan: 3 steps
#   to Azor-Ahai: 3 steps
#   to Edric-Storm: 3 steps
#   to Khorane-Sathmantes: 3 steps
#   to Wyman-Manderly: 3 steps
#   to Theomore: 3 steps
#   to William-Foxglove: 3 steps
#   to Arnolf-Karstark: 3 steps
#   to Mors-Umber: 3 steps
#   to Clayton-Suggs: 3 steps
#   to Corliss-Penny: 3 steps
#   to Marlon-Manderly: 3 steps
#   to Lyanna-Mormont: 3 steps
#   to Marya-Seaworth: 3 steps
#   to Roose-Ryswell: 3 steps
#   to Jafer-Flowers: 3 steps
#   to Mallador-Locke: 3 steps
#   to Softfoot: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Bael-the-Bard: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Guncer-Sunglass: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Benethon-Scales: 3 steps
#   to Brus-Buckler: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Imry-Florent: 4 steps
#   to Matthos-Seaworth: 4 steps
#   to Andrew-Estermont: 4 steps
#   to Bartimus: 4 steps
#   to Sybell-Spicer: 4 steps
#   to Garth-(Wolfs-Den): 4 steps
#   to Godric-Borrell: 4 steps
#   to Leona-Woolfield: 4 steps
#   to Ardrian-Celtigar: 4 steps
#   to Hother-Umber: 4 steps
#   to Arthor-Karstark: 4 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gerald-Gower: 5 steps
#   to Gawen-Westerling: 5 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Selyse-Florent:
#   to Selyse-Florent: 0 steps
#   to Axell-Florent: 1 steps
#   to Cressen: 1 steps
#   to Melisandre: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Alester-Florent: 1 steps
#   to Davos-Seaworth: 1 steps
#   to Jon-Snow: 1 steps
#   to Satin: 1 steps
#   to Shireen-Baratheon: 1 steps
#   to Val: 1 steps
#   to Wun-Weg-Wun-Dar-Wun: 1 steps
#   to Benethon-Scales: 1 steps
#   to Narbert-Grandison: 1 steps
#   to Brus-Buckler: 1 steps
#   to Malegorn: 1 steps
#   to Cotter-Pyke: 1 steps
#   to Patrek-of-Kings-Mountain: 1 steps
#   to Patchface: 1 steps
#   to Lamprey: 2 steps
#   to Porridge: 2 steps
#   to Salladhor-Saan: 2 steps
#   to Pylos: 2 steps
#   to Guncer-Sunglass: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Gilly: 2 steps
#   to Dalla: 2 steps
#   to Sigorn: 2 steps
#   to Rattleshirt: 2 steps
#   to Ygritte: 2 steps
#   to Alys-Karstark: 2 steps
#   to Mance-Rayder: 2 steps
#   to Godry-Farring: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Hobb: 2 steps
#   to Joramun: 2 steps
#   to Allard-Seaworth: 2 steps
#   to Cortnay-Penrose: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Alliser-Thorne: 2 steps
#   to Azor-Ahai: 2 steps
#   to Donal-Noye: 2 steps
#   to Edric-Storm: 2 steps
#   to Janos-Slynt: 2 steps
#   to Khorane-Sathmantes: 2 steps
#   to Clydas: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Clayton-Suggs: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Corliss-Penny: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Marya-Seaworth: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Imry-Florent: 2 steps
#   to Matthos-Seaworth: 2 steps
#   to Andrew-Estermont: 2 steps
#   to Bartimus: 2 steps
#   to Sybell-Spicer: 2 steps
#   to Garth-(Wolfs-Den): 2 steps
#   to Godric-Borrell: 2 steps
#   to Leona-Woolfield: 2 steps
#   to Albett: 2 steps
#   to Chett: 2 steps
#   to Dareon: 2 steps
#   to Dywen: 2 steps
#   to Grenn: 2 steps
#   to Halder: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Jeor-Mormont: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Pypar: 2 steps
#   to Rast: 2 steps
#   to Todder: 2 steps
#   to Craster: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Hake: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Lark: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Stonesnake: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Owen: 2 steps
#   to Ryk: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Denys-Mallister: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Arron: 2 steps
#   to Emrick: 2 steps
#   to Daeron-I-Targaryen: 2 steps
#   to Bannen: 3 steps
#   to Bedwyck: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Small-Paul: 3 steps
#   to Alleras: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Bael-the-Bard: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Wynton-Stout: 3 steps
#   to Hother-Umber: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Gerald-Gower: 3 steps
#   to Gawen-Westerling: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Jafer-Flowers: 3 steps
#   to Blane: 3 steps
#   to Byam-Flint: 3 steps
#   to Watt: 3 steps
#   to Softfoot: 3 steps
#   to Ragwyle: 3 steps
#   to Mallador-Locke: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Armen: 4 steps
#   to Mollander: 4 steps
#   to Pate-(novice): 4 steps
#   to Roone: 4 steps
#   to Walgrave: 5 steps
#   to Quill: 5 steps
#   to Rosey: 5 steps
#   to Gormon-Tyrell: 6 steps
# Shortest paths from node Salladhor-Saan:
#   to Salladhor-Saan: 0 steps
#   to Davos-Seaworth: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Axell-Florent: 1 steps
#   to Khorane-Sathmantes: 1 steps
#   to Melisandre: 1 steps
#   to Alester-Florent: 2 steps
#   to Allard-Seaworth: 2 steps
#   to Cortnay-Penrose: 2 steps
#   to Cressen: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Imry-Florent: 2 steps
#   to Matthos-Seaworth: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Pylos: 2 steps
#   to Andrew-Estermont: 2 steps
#   to Edric-Storm: 2 steps
#   to Guncer-Sunglass: 2 steps
#   to Lamprey: 2 steps
#   to Porridge: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Bartimus: 2 steps
#   to Sybell-Spicer: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Garth-(Wolfs-Den): 2 steps
#   to Godric-Borrell: 2 steps
#   to Leona-Woolfield: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Patchface: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Alliser-Thorne: 2 steps
#   to Azor-Ahai: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Donal-Noye: 2 steps
#   to Janos-Slynt: 2 steps
#   to Jon-Snow: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Clydas: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Val: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Dalla: 2 steps
#   to Sigorn: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Mance-Rayder: 2 steps
#   to Clayton-Suggs: 2 steps
#   to Godry-Farring: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Corliss-Penny: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Marya-Seaworth: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Gilly: 2 steps
#   to Rattleshirt: 2 steps
#   to Ygritte: 2 steps
#   to Alys-Karstark: 2 steps
#   to Hobb: 2 steps
#   to Joramun: 2 steps
#   to Ardrian-Celtigar: 3 steps
#   to Gerald-Gower: 3 steps
#   to Satin: 3 steps
#   to Wun-Weg-Wun-Dar-Wun: 3 steps
#   to Benethon-Scales: 3 steps
#   to Narbert-Grandison: 3 steps
#   to Brus-Buckler: 3 steps
#   to Malegorn: 3 steps
#   to Patrek-of-Kings-Mountain: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Gawen-Westerling: 3 steps
#   to Hother-Umber: 3 steps
#   to Chett: 3 steps
#   to Jeor-Mormont: 3 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Denys-Mallister: 3 steps
#   to Eddison-Tollett: 3 steps
#   to Grenn: 3 steps
#   to Owen: 3 steps
#   to Pypar: 3 steps
#   to Wynton-Stout: 3 steps
#   to Alleras: 3 steps
#   to Dareon: 3 steps
#   to Halder: 3 steps
#   to Rast: 3 steps
#   to Qhorin-Halfhand: 3 steps
#   to Othell-Yarwyck: 3 steps
#   to Mag-Mar-Tun-Doh-Weg: 3 steps
#   to Emmett: 3 steps
#   to Albett: 3 steps
#   to Dywen: 3 steps
#   to Jaremy-Rykker: 3 steps
#   to Matthar: 3 steps
#   to Othor: 3 steps
#   to Todder: 3 steps
#   to Craster: 3 steps
#   to Dalbridge: 3 steps
#   to Ebben: 3 steps
#   to Hake: 3 steps
#   to Jarman-Buckwell: 3 steps
#   to Lark: 3 steps
#   to Ottyn-Wythers: 3 steps
#   to Stonesnake: 3 steps
#   to Thoren-Smallwood: 3 steps
#   to Arson: 3 steps
#   to Big-Boil: 3 steps
#   to Dick-Follard: 3 steps
#   to Errok: 3 steps
#   to Gendel: 3 steps
#   to Gorne: 3 steps
#   to Grigg: 3 steps
#   to Hareth-(Moles-Town): 3 steps
#   to Harma: 3 steps
#   to Jarl: 3 steps
#   to Kegs: 3 steps
#   to Mully: 3 steps
#   to Orell: 3 steps
#   to Ryk: 3 steps
#   to Spare-Boot: 3 steps
#   to Styr: 3 steps
#   to Tormund: 3 steps
#   to Varamyr: 3 steps
#   to Zei: 3 steps
#   to Wick-Whittlestick: 3 steps
#   to Leathers: 3 steps
#   to Rory: 3 steps
#   to Soren-Shieldbreaker: 3 steps
#   to Tom-Barleycorn: 3 steps
#   to Toregg: 3 steps
#   to Ulmer: 3 steps
#   to Weeper: 3 steps
#   to Cellador: 3 steps
#   to Brandon-Norrey: 3 steps
#   to Hop-Robin: 3 steps
#   to Fulk: 3 steps
#   to Gerrick-Kingsblood: 3 steps
#   to Bannen: 3 steps
#   to Bedwyck: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Small-Paul: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Bael-the-Bard: 3 steps
#   to Arron: 4 steps
#   to Emrick: 4 steps
#   to Blane: 4 steps
#   to Watt: 4 steps
#   to Armen: 4 steps
#   to Mollander: 4 steps
#   to Pate-(novice): 4 steps
#   to Roone: 4 steps
#   to Lanna-(Happy-Port): 4 steps
#   to Ragwyle: 4 steps
#   to Jafer-Flowers: 4 steps
#   to Byam-Flint: 4 steps
#   to Softfoot: 4 steps
#   to Mallador-Locke: 4 steps
#   to Munda: 4 steps
#   to Dryn: 4 steps
#   to Bump: 4 steps
#   to Haggon: 4 steps
#   to Thistle: 4 steps
#   to Torghen-Flint: 4 steps
#   to Raymun-Redbeard: 4 steps
#   to Walgrave: 5 steps
#   to Quill: 5 steps
#   to Rosey: 5 steps
#   to Gormon-Tyrell: 6 steps
# Shortest paths from node Rast:
#   to Rast: 0 steps
#   to Albett: 1 steps
#   to Alliser-Thorne: 1 steps
#   to Halder: 1 steps
#   to Jon-Snow: 1 steps
#   to Pypar: 1 steps
#   to Samwell-Tarly: 1 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Bowen-Marsh: 2 steps
#   to Grenn: 2 steps
#   to Jeor-Mormont: 2 steps
#   to Janos-Slynt: 2 steps
#   to Mance-Rayder: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Stannis-Baratheon: 2 steps
#   to Todder: 2 steps
#   to Chett: 2 steps
#   to Dareon: 2 steps
#   to Donal-Noye: 2 steps
#   to Dywen: 2 steps
#   to Hobb: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Craster: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Hake: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Lark: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Clydas: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gilly: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Melisandre: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Owen: 2 steps
#   to Ryk: 2 steps
#   to Satin: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Godry-Farring: 2 steps
#   to Axell-Florent: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Denys-Mallister: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Bannen: 2 steps
#   to Bedwyck: 2 steps
#   to Clubfoot-Karl: 2 steps
#   to Dirk: 2 steps
#   to Small-Paul: 2 steps
#   to Alleras: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Wynton-Stout: 3 steps
#   to Blane: 3 steps
#   to Joramun: 3 steps
#   to Ragwyle: 3 steps
#   to Alester-Florent: 3 steps
#   to Allard-Seaworth: 3 steps
#   to Cortnay-Penrose: 3 steps
#   to Cressen: 3 steps
#   to Davos-Seaworth: 3 steps
#   to Monford-Velaryon: 3 steps
#   to Patchface: 3 steps
#   to Pylos: 3 steps
#   to Salladhor-Saan: 3 steps
#   to Azor-Ahai: 3 steps
#   to Edric-Storm: 3 steps
#   to Khorane-Sathmantes: 3 steps
#   to Wyman-Manderly: 3 steps
#   to Theomore: 3 steps
#   to William-Foxglove: 3 steps
#   to Arnolf-Karstark: 3 steps
#   to Mors-Umber: 3 steps
#   to Clayton-Suggs: 3 steps
#   to Corliss-Penny: 3 steps
#   to Marlon-Manderly: 3 steps
#   to Lyanna-Mormont: 3 steps
#   to Marya-Seaworth: 3 steps
#   to Roose-Ryswell: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Jafer-Flowers: 3 steps
#   to Byam-Flint: 3 steps
#   to Watt: 3 steps
#   to Softfoot: 3 steps
#   to Mallador-Locke: 3 steps
#   to Bael-the-Bard: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Guncer-Sunglass: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Benethon-Scales: 3 steps
#   to Brus-Buckler: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Imry-Florent: 4 steps
#   to Matthos-Seaworth: 4 steps
#   to Andrew-Estermont: 4 steps
#   to Bartimus: 4 steps
#   to Sybell-Spicer: 4 steps
#   to Garth-(Wolfs-Den): 4 steps
#   to Godric-Borrell: 4 steps
#   to Leona-Woolfield: 4 steps
#   to Ardrian-Celtigar: 4 steps
#   to Hother-Umber: 4 steps
#   to Arthor-Karstark: 4 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gerald-Gower: 5 steps
#   to Gawen-Westerling: 5 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Craster:
#   to Craster: 0 steps
#   to Dywen: 1 steps
#   to Eddison-Tollett: 1 steps
#   to Jeor-Mormont: 1 steps
#   to Jon-Snow: 1 steps
#   to Mance-Rayder: 1 steps
#   to Samwell-Tarly: 1 steps
#   to Thoren-Smallwood: 1 steps
#   to Bedwyck: 1 steps
#   to Byam-Flint: 1 steps
#   to Clubfoot-Karl: 1 steps
#   to Dirk: 1 steps
#   to Gilly: 1 steps
#   to Grenn: 1 steps
#   to Tormund: 1 steps
#   to Bannen: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Bowen-Marsh: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Denys-Mallister: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Pypar: 2 steps
#   to Watt: 2 steps
#   to Satin: 2 steps
#   to Mully: 2 steps
#   to Emmett: 2 steps
#   to Hobb: 2 steps
#   to Janos-Slynt: 2 steps
#   to Alliser-Thorne: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Blane: 2 steps
#   to Chett: 2 steps
#   to Donal-Noye: 2 steps
#   to Lark: 2 steps
#   to Small-Paul: 2 steps
#   to Albett: 2 steps
#   to Dareon: 2 steps
#   to Halder: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Rast: 2 steps
#   to Todder: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Hake: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Clydas: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Melisandre: 2 steps
#   to Orell: 2 steps
#   to Owen: 2 steps
#   to Ryk: 2 steps
#   to Spare-Boot: 2 steps
#   to Stannis-Baratheon: 2 steps
#   to Styr: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Godry-Farring: 2 steps
#   to Axell-Florent: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Joramun: 2 steps
#   to Alleras: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Mallador-Locke: 2 steps
#   to Munda: 2 steps
#   to Dryn: 2 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Wynton-Stout: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Jafer-Flowers: 3 steps
#   to Ragwyle: 3 steps
#   to Softfoot: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Bael-the-Bard: 3 steps
#   to Cressen: 3 steps
#   to Davos-Seaworth: 3 steps
#   to Guncer-Sunglass: 3 steps
#   to Salladhor-Saan: 3 steps
#   to Alester-Florent: 3 steps
#   to Allard-Seaworth: 3 steps
#   to Cortnay-Penrose: 3 steps
#   to Monford-Velaryon: 3 steps
#   to Patchface: 3 steps
#   to Pylos: 3 steps
#   to Azor-Ahai: 3 steps
#   to Edric-Storm: 3 steps
#   to Khorane-Sathmantes: 3 steps
#   to Wyman-Manderly: 3 steps
#   to Theomore: 3 steps
#   to William-Foxglove: 3 steps
#   to Arnolf-Karstark: 3 steps
#   to Mors-Umber: 3 steps
#   to Clayton-Suggs: 3 steps
#   to Corliss-Penny: 3 steps
#   to Marlon-Manderly: 3 steps
#   to Lyanna-Mormont: 3 steps
#   to Marya-Seaworth: 3 steps
#   to Roose-Ryswell: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Benethon-Scales: 3 steps
#   to Brus-Buckler: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Imry-Florent: 4 steps
#   to Matthos-Seaworth: 4 steps
#   to Andrew-Estermont: 4 steps
#   to Bartimus: 4 steps
#   to Sybell-Spicer: 4 steps
#   to Garth-(Wolfs-Den): 4 steps
#   to Godric-Borrell: 4 steps
#   to Leona-Woolfield: 4 steps
#   to Ardrian-Celtigar: 4 steps
#   to Hother-Umber: 4 steps
#   to Arthor-Karstark: 4 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gerald-Gower: 5 steps
#   to Gawen-Westerling: 5 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Aemon-Targaryen-(Maester-Aemon):
#   to Aemon-Targaryen-(Maester-Aemon): 0 steps
#   to Alliser-Thorne: 1 steps
#   to Bowen-Marsh: 1 steps
#   to Chett: 1 steps
#   to Clydas: 1 steps
#   to Jeor-Mormont: 1 steps
#   to Jon-Snow: 1 steps
#   to Samwell-Tarly: 1 steps
#   to Aegon-V-Targaryen: 1 steps
#   to Daeron-II-Targaryen: 1 steps
#   to Maekar-I-Targaryen: 1 steps
#   to Cotter-Pyke: 1 steps
#   to Denys-Mallister: 1 steps
#   to Donal-Noye: 1 steps
#   to Eddison-Tollett: 1 steps
#   to Grenn: 1 steps
#   to Hobb: 1 steps
#   to Janos-Slynt: 1 steps
#   to Mance-Rayder: 1 steps
#   to Owen: 1 steps
#   to Pypar: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Wynton-Stout: 1 steps
#   to Alleras: 1 steps
#   to Dareon: 1 steps
#   to Gilly: 1 steps
#   to Halder: 2 steps
#   to Rast: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Satin: 2 steps
#   to Cellador: 2 steps
#   to Tormund: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Lark: 2 steps
#   to Small-Paul: 2 steps
#   to Mully: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Craster: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Blane: 2 steps
#   to Dywen: 2 steps
#   to Albett: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Todder: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Hake: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Melisandre: 2 steps
#   to Orell: 2 steps
#   to Ryk: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Godry-Farring: 2 steps
#   to Axell-Florent: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Bannen: 2 steps
#   to Bedwyck: 2 steps
#   to Clubfoot-Karl: 2 steps
#   to Dirk: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Watt: 2 steps
#   to Joramun: 2 steps
#   to Alester-Florent: 2 steps
#   to Allard-Seaworth: 2 steps
#   to Cortnay-Penrose: 2 steps
#   to Cressen: 2 steps
#   to Davos-Seaworth: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Patchface: 2 steps
#   to Pylos: 2 steps
#   to Salladhor-Saan: 2 steps
#   to Azor-Ahai: 2 steps
#   to Edric-Storm: 2 steps
#   to Khorane-Sathmantes: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Clayton-Suggs: 2 steps
#   to Corliss-Penny: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Marya-Seaworth: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Armen: 2 steps
#   to Mollander: 2 steps
#   to Pate-(novice): 2 steps
#   to Roone: 2 steps
#   to Lanna-(Happy-Port): 2 steps
#   to Ragwyle: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Softfoot: 3 steps
#   to Jafer-Flowers: 3 steps
#   to Byam-Flint: 3 steps
#   to Mallador-Locke: 3 steps
#   to Bael-the-Bard: 3 steps
#   to Guncer-Sunglass: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Benethon-Scales: 3 steps
#   to Brus-Buckler: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Imry-Florent: 3 steps
#   to Matthos-Seaworth: 3 steps
#   to Andrew-Estermont: 3 steps
#   to Bartimus: 3 steps
#   to Sybell-Spicer: 3 steps
#   to Garth-(Wolfs-Den): 3 steps
#   to Godric-Borrell: 3 steps
#   to Leona-Woolfield: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Hother-Umber: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Walgrave: 3 steps
#   to Quill: 3 steps
#   to Rosey: 3 steps
#   to Gerald-Gower: 4 steps
#   to Gawen-Westerling: 4 steps
#   to Gormon-Tyrell: 4 steps
# Shortest paths from node Jon-Snow:
#   to Jon-Snow: 0 steps
#   to Aemon-Targaryen-(Maester-Aemon): 1 steps
#   to Albett: 1 steps
#   to Alliser-Thorne: 1 steps
#   to Bowen-Marsh: 1 steps
#   to Chett: 1 steps
#   to Dareon: 1 steps
#   to Donal-Noye: 1 steps
#   to Dywen: 1 steps
#   to Grenn: 1 steps
#   to Halder: 1 steps
#   to Hobb: 1 steps
#   to Jaremy-Rykker: 1 steps
#   to Jeor-Mormont: 1 steps
#   to Matthar: 1 steps
#   to Othor: 1 steps
#   to Pypar: 1 steps
#   to Rast: 1 steps
#   to Samwell-Tarly: 1 steps
#   to Todder: 1 steps
#   to Craster: 1 steps
#   to Dalbridge: 1 steps
#   to Ebben: 1 steps
#   to Eddison-Tollett: 1 steps
#   to Hake: 1 steps
#   to Jarman-Buckwell: 1 steps
#   to Lark: 1 steps
#   to Mance-Rayder: 1 steps
#   to Ottyn-Wythers: 1 steps
#   to Qhorin-Halfhand: 1 steps
#   to Rattleshirt: 1 steps
#   to Stonesnake: 1 steps
#   to Thoren-Smallwood: 1 steps
#   to Ygritte: 1 steps
#   to Arson: 1 steps
#   to Big-Boil: 1 steps
#   to Clydas: 1 steps
#   to Cotter-Pyke: 1 steps
#   to Dalla: 1 steps
#   to Dick-Follard: 1 steps
#   to Errok: 1 steps
#   to Gendel: 1 steps
#   to Gilly: 1 steps
#   to Gorne: 1 steps
#   to Grigg: 1 steps
#   to Hareth-(Moles-Town): 1 steps
#   to Harma: 1 steps
#   to Janos-Slynt: 1 steps
#   to Jarl: 1 steps
#   to Kegs: 1 steps
#   to Mag-Mar-Tun-Doh-Weg: 1 steps
#   to Melisandre: 1 steps
#   to Mully: 1 steps
#   to Orell: 1 steps
#   to Owen: 1 steps
#   to Ryk: 1 steps
#   to Satin: 1 steps
#   to Spare-Boot: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Styr: 1 steps
#   to Tormund: 1 steps
#   to Val: 1 steps
#   to Varamyr: 1 steps
#   to Zei: 1 steps
#   to Sigorn: 1 steps
#   to Tycho-Nestoris: 1 steps
#   to Selyse-Florent: 1 steps
#   to Shireen-Baratheon: 1 steps
#   to Narbert-Grandison: 1 steps
#   to Othell-Yarwyck: 1 steps
#   to Wick-Whittlestick: 1 steps
#   to Malegorn: 1 steps
#   to Leathers: 1 steps
#   to Rory: 1 steps
#   to Patrek-of-Kings-Mountain: 1 steps
#   to Soren-Shieldbreaker: 1 steps
#   to Tom-Barleycorn: 1 steps
#   to Toregg: 1 steps
#   to Ulmer: 1 steps
#   to Weeper: 1 steps
#   to Wun-Weg-Wun-Dar-Wun: 1 steps
#   to Alys-Karstark: 1 steps
#   to Godry-Farring: 1 steps
#   to Axell-Florent: 1 steps
#   to Cellador: 1 steps
#   to Brandon-Norrey: 1 steps
#   to Denys-Mallister: 1 steps
#   to Devan-Seaworth: 1 steps
#   to Emmett: 1 steps
#   to Hop-Robin: 1 steps
#   to Fulk: 1 steps
#   to Gerrick-Kingsblood: 1 steps
#   to Aegon-V-Targaryen: 2 steps
#   to Daeron-II-Targaryen: 2 steps
#   to Maekar-I-Targaryen: 2 steps
#   to Wynton-Stout: 2 steps
#   to Alleras: 2 steps
#   to Small-Paul: 2 steps
#   to Lanna-(Happy-Port): 2 steps
#   to Bannen: 2 steps
#   to Bedwyck: 2 steps
#   to Jafer-Flowers: 2 steps
#   to Blane: 2 steps
#   to Clubfoot-Karl: 2 steps
#   to Dirk: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Byam-Flint: 2 steps
#   to Watt: 2 steps
#   to Softfoot: 2 steps
#   to Joramun: 2 steps
#   to Ragwyle: 2 steps
#   to Mallador-Locke: 2 steps
#   to Bael-the-Bard: 2 steps
#   to Arron: 2 steps
#   to Emrick: 2 steps
#   to Cressen: 2 steps
#   to Davos-Seaworth: 2 steps
#   to Guncer-Sunglass: 2 steps
#   to Salladhor-Saan: 2 steps
#   to Alester-Florent: 2 steps
#   to Allard-Seaworth: 2 steps
#   to Cortnay-Penrose: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Patchface: 2 steps
#   to Pylos: 2 steps
#   to Azor-Ahai: 2 steps
#   to Edric-Storm: 2 steps
#   to Khorane-Sathmantes: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Clayton-Suggs: 2 steps
#   to Corliss-Penny: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Marya-Seaworth: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Munda: 2 steps
#   to Dryn: 2 steps
#   to Bump: 2 steps
#   to Haggon: 2 steps
#   to Thistle: 2 steps
#   to Benethon-Scales: 2 steps
#   to Brus-Buckler: 2 steps
#   to Daeron-I-Targaryen: 2 steps
#   to Lamprey: 2 steps
#   to Porridge: 2 steps
#   to Torghen-Flint: 2 steps
#   to Raymun-Redbeard: 2 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Imry-Florent: 3 steps
#   to Matthos-Seaworth: 3 steps
#   to Andrew-Estermont: 3 steps
#   to Bartimus: 3 steps
#   to Sybell-Spicer: 3 steps
#   to Garth-(Wolfs-Den): 3 steps
#   to Godric-Borrell: 3 steps
#   to Leona-Woolfield: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Hother-Umber: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gerald-Gower: 4 steps
#   to Gawen-Westerling: 4 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Chett:
#   to Chett: 0 steps
#   to Aemon-Targaryen-(Maester-Aemon): 1 steps
#   to Jon-Snow: 1 steps
#   to Samwell-Tarly: 1 steps
#   to Jeor-Mormont: 1 steps
#   to Lark: 1 steps
#   to Qhorin-Halfhand: 1 steps
#   to Small-Paul: 1 steps
#   to Alliser-Thorne: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Clydas: 2 steps
#   to Aegon-V-Targaryen: 2 steps
#   to Daeron-II-Targaryen: 2 steps
#   to Maekar-I-Targaryen: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Denys-Mallister: 2 steps
#   to Donal-Noye: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Grenn: 2 steps
#   to Hobb: 2 steps
#   to Janos-Slynt: 2 steps
#   to Mance-Rayder: 2 steps
#   to Owen: 2 steps
#   to Pypar: 2 steps
#   to Stannis-Baratheon: 2 steps
#   to Wynton-Stout: 2 steps
#   to Alleras: 2 steps
#   to Dareon: 2 steps
#   to Gilly: 2 steps
#   to Albett: 2 steps
#   to Dywen: 2 steps
#   to Halder: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Rast: 2 steps
#   to Todder: 2 steps
#   to Craster: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Hake: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Melisandre: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Ryk: 2 steps
#   to Satin: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Godry-Farring: 2 steps
#   to Axell-Florent: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Bannen: 2 steps
#   to Bedwyck: 2 steps
#   to Clubfoot-Karl: 2 steps
#   to Dirk: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Blane: 2 steps
#   to Softfoot: 2 steps
#   to Ragwyle: 2 steps
#   to Watt: 3 steps
#   to Joramun: 3 steps
#   to Alester-Florent: 3 steps
#   to Allard-Seaworth: 3 steps
#   to Cortnay-Penrose: 3 steps
#   to Cressen: 3 steps
#   to Davos-Seaworth: 3 steps
#   to Monford-Velaryon: 3 steps
#   to Patchface: 3 steps
#   to Pylos: 3 steps
#   to Salladhor-Saan: 3 steps
#   to Azor-Ahai: 3 steps
#   to Edric-Storm: 3 steps
#   to Khorane-Sathmantes: 3 steps
#   to Wyman-Manderly: 3 steps
#   to Theomore: 3 steps
#   to William-Foxglove: 3 steps
#   to Arnolf-Karstark: 3 steps
#   to Mors-Umber: 3 steps
#   to Clayton-Suggs: 3 steps
#   to Corliss-Penny: 3 steps
#   to Marlon-Manderly: 3 steps
#   to Lyanna-Mormont: 3 steps
#   to Marya-Seaworth: 3 steps
#   to Roose-Ryswell: 3 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Jafer-Flowers: 3 steps
#   to Byam-Flint: 3 steps
#   to Mallador-Locke: 3 steps
#   to Bael-the-Bard: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Guncer-Sunglass: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Benethon-Scales: 3 steps
#   to Brus-Buckler: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Imry-Florent: 4 steps
#   to Matthos-Seaworth: 4 steps
#   to Andrew-Estermont: 4 steps
#   to Bartimus: 4 steps
#   to Sybell-Spicer: 4 steps
#   to Garth-(Wolfs-Den): 4 steps
#   to Godric-Borrell: 4 steps
#   to Leona-Woolfield: 4 steps
#   to Ardrian-Celtigar: 4 steps
#   to Hother-Umber: 4 steps
#   to Arthor-Karstark: 4 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gerald-Gower: 5 steps
#   to Gawen-Westerling: 5 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Albett:
#   to Albett: 0 steps
#   to Halder: 1 steps
#   to Jon-Snow: 1 steps
#   to Rast: 1 steps
#   to Alliser-Thorne: 2 steps
#   to Grenn: 2 steps
#   to Pypar: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Todder: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Bowen-Marsh: 2 steps
#   to Chett: 2 steps
#   to Dareon: 2 steps
#   to Donal-Noye: 2 steps
#   to Dywen: 2 steps
#   to Hobb: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Jeor-Mormont: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Craster: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Hake: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Lark: 2 steps
#   to Mance-Rayder: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Clydas: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gilly: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Janos-Slynt: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Melisandre: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Owen: 2 steps
#   to Ryk: 2 steps
#   to Satin: 2 steps
#   to Spare-Boot: 2 steps
#   to Stannis-Baratheon: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Godry-Farring: 2 steps
#   to Axell-Florent: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Denys-Mallister: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Bedwyck: 3 steps
#   to Small-Paul: 3 steps
#   to Bannen: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Alleras: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Wynton-Stout: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Jafer-Flowers: 3 steps
#   to Blane: 3 steps
#   to Byam-Flint: 3 steps
#   to Watt: 3 steps
#   to Softfoot: 3 steps
#   to Joramun: 3 steps
#   to Ragwyle: 3 steps
#   to Mallador-Locke: 3 steps
#   to Bael-the-Bard: 3 steps
# ...
#   to Jeor-Mormont: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Pypar: 2 steps
#   to Rast: 2 steps
#   to Todder: 2 steps
#   to Craster: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Hake: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Lark: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Stonesnake: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Owen: 2 steps
#   to Ryk: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Denys-Mallister: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Bannen: 2 steps
#   to Bedwyck: 2 steps
#   to Clubfoot-Karl: 2 steps
#   to Dirk: 2 steps
#   to Small-Paul: 2 steps
#   to Alleras: 2 steps
#   to Xhondo: 2 steps
#   to Theobald: 2 steps
#   to Leo-Tyrell: 2 steps
#   to Marwyn: 2 steps
#   to Kojja-Mo: 2 steps
#   to Quhuru-Mo: 2 steps
#   to Bael-the-Bard: 2 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Gerald-Gower: 3 steps
#   to Gawen-Westerling: 3 steps
#   to Hother-Umber: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Wynton-Stout: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Jafer-Flowers: 3 steps
#   to Blane: 3 steps
#   to Byam-Flint: 3 steps
#   to Watt: 3 steps
#   to Softfoot: 3 steps
#   to Ragwyle: 3 steps
#   to Mallador-Locke: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Wynton-Stout:
#   to Wynton-Stout: 0 steps
#   to Aemon-Targaryen-(Maester-Aemon): 1 steps
#   to Alliser-Thorne: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Chett: 2 steps
#   to Clydas: 2 steps
#   to Jeor-Mormont: 2 steps
#   to Jon-Snow: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Aegon-V-Targaryen: 2 steps
#   to Daeron-II-Targaryen: 2 steps
#   to Maekar-I-Targaryen: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Denys-Mallister: 2 steps
#   to Donal-Noye: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Grenn: 2 steps
#   to Hobb: 2 steps
#   to Janos-Slynt: 2 steps
#   to Mance-Rayder: 2 steps
#   to Owen: 2 steps
#   to Pypar: 2 steps
#   to Stannis-Baratheon: 2 steps
#   to Alleras: 2 steps
#   to Dareon: 2 steps
#   to Gilly: 2 steps
#   to Halder: 3 steps
#   to Rast: 3 steps
#   to Qhorin-Halfhand: 3 steps
#   to Othell-Yarwyck: 3 steps
#   to Satin: 3 steps
#   to Cellador: 3 steps
#   to Tormund: 3 steps
#   to Wick-Whittlestick: 3 steps
#   to Lark: 3 steps
#   to Small-Paul: 3 steps
#   to Mully: 3 steps
#   to Jaremy-Rykker: 3 steps
#   to Craster: 3 steps
#   to Jarman-Buckwell: 3 steps
#   to Ottyn-Wythers: 3 steps
#   to Thoren-Smallwood: 3 steps
#   to Blane: 3 steps
#   to Dywen: 3 steps
#   to Albett: 3 steps
#   to Matthar: 3 steps
#   to Othor: 3 steps
#   to Todder: 3 steps
#   to Dalbridge: 3 steps
#   to Ebben: 3 steps
#   to Hake: 3 steps
#   to Rattleshirt: 3 steps
#   to Stonesnake: 3 steps
#   to Ygritte: 3 steps
#   to Arson: 3 steps
#   to Big-Boil: 3 steps
#   to Dalla: 3 steps
#   to Dick-Follard: 3 steps
#   to Errok: 3 steps
#   to Gendel: 3 steps
#   to Gorne: 3 steps
#   to Grigg: 3 steps
#   to Hareth-(Moles-Town): 3 steps
#   to Harma: 3 steps
#   to Jarl: 3 steps
#   to Kegs: 3 steps
#   to Mag-Mar-Tun-Doh-Weg: 3 steps
#   to Melisandre: 3 steps
#   to Orell: 3 steps
#   to Ryk: 3 steps
#   to Spare-Boot: 3 steps
#   to Styr: 3 steps
#   to Val: 3 steps
#   to Varamyr: 3 steps
#   to Zei: 3 steps
#   to Sigorn: 3 steps
#   to Tycho-Nestoris: 3 steps
#   to Selyse-Florent: 3 steps
#   to Shireen-Baratheon: 3 steps
#   to Narbert-Grandison: 3 steps
#   to Malegorn: 3 steps
#   to Leathers: 3 steps
#   to Rory: 3 steps
#   to Patrek-of-Kings-Mountain: 3 steps
#   to Soren-Shieldbreaker: 3 steps
#   to Tom-Barleycorn: 3 steps
#   to Toregg: 3 steps
#   to Ulmer: 3 steps
#   to Weeper: 3 steps
#   to Wun-Weg-Wun-Dar-Wun: 3 steps
#   to Alys-Karstark: 3 steps
#   to Godry-Farring: 3 steps
#   to Axell-Florent: 3 steps
#   to Brandon-Norrey: 3 steps
#   to Devan-Seaworth: 3 steps
#   to Emmett: 3 steps
#   to Hop-Robin: 3 steps
#   to Fulk: 3 steps
#   to Gerrick-Kingsblood: 3 steps
#   to Bannen: 3 steps
#   to Bedwyck: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Watt: 3 steps
#   to Joramun: 3 steps
#   to Alester-Florent: 3 steps
#   to Allard-Seaworth: 3 steps
#   to Cortnay-Penrose: 3 steps
#   to Cressen: 3 steps
#   to Davos-Seaworth: 3 steps
#   to Monford-Velaryon: 3 steps
#   to Patchface: 3 steps
#   to Pylos: 3 steps
#   to Salladhor-Saan: 3 steps
#   to Azor-Ahai: 3 steps
#   to Edric-Storm: 3 steps
#   to Khorane-Sathmantes: 3 steps
#   to Wyman-Manderly: 3 steps
#   to Theomore: 3 steps
#   to William-Foxglove: 3 steps
#   to Arnolf-Karstark: 3 steps
#   to Mors-Umber: 3 steps
#   to Clayton-Suggs: 3 steps
#   to Corliss-Penny: 3 steps
#   to Marlon-Manderly: 3 steps
#   to Lyanna-Mormont: 3 steps
#   to Marya-Seaworth: 3 steps
#   to Roose-Ryswell: 3 steps
#   to Armen: 3 steps
#   to Mollander: 3 steps
#   to Pate-(novice): 3 steps
#   to Roone: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Ragwyle: 4 steps
#   to Arron: 4 steps
#   to Emrick: 4 steps
#   to Munda: 4 steps
#   to Dryn: 4 steps
#   to Softfoot: 4 steps
#   to Jafer-Flowers: 4 steps
#   to Byam-Flint: 4 steps
#   to Mallador-Locke: 4 steps
#   to Bael-the-Bard: 4 steps
#   to Guncer-Sunglass: 4 steps
#   to Bump: 4 steps
#   to Haggon: 4 steps
#   to Thistle: 4 steps
#   to Benethon-Scales: 4 steps
#   to Brus-Buckler: 4 steps
#   to Daeron-I-Targaryen: 4 steps
#   to Lamprey: 4 steps
#   to Porridge: 4 steps
#   to Torghen-Flint: 4 steps
#   to Raymun-Redbeard: 4 steps
#   to Imry-Florent: 4 steps
#   to Matthos-Seaworth: 4 steps
#   to Andrew-Estermont: 4 steps
#   to Bartimus: 4 steps
#   to Sybell-Spicer: 4 steps
#   to Garth-(Wolfs-Den): 4 steps
#   to Godric-Borrell: 4 steps
#   to Leona-Woolfield: 4 steps
#   to Ardrian-Celtigar: 4 steps
#   to Hother-Umber: 4 steps
#   to Arthor-Karstark: 4 steps
#   to Walgrave: 4 steps
#   to Quill: 4 steps
#   to Rosey: 4 steps
#   to Gerald-Gower: 5 steps
#   to Gawen-Westerling: 5 steps
#   to Gormon-Tyrell: 5 steps
# Shortest paths from node Alester-Florent:
#   to Alester-Florent: 0 steps
#   to Cortnay-Penrose: 1 steps
#   to Davos-Seaworth: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Axell-Florent: 1 steps
#   to Lamprey: 1 steps
#   to Selyse-Florent: 1 steps
#   to Allard-Seaworth: 2 steps
#   to Cressen: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Imry-Florent: 2 steps
#   to Matthos-Seaworth: 2 steps
#   to Melisandre: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Pylos: 2 steps
#   to Salladhor-Saan: 2 steps
#   to Andrew-Estermont: 2 steps
#   to Edric-Storm: 2 steps
#   to Guncer-Sunglass: 2 steps
#   to Khorane-Sathmantes: 2 steps
#   to Porridge: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Bartimus: 2 steps
#   to Sybell-Spicer: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Garth-(Wolfs-Den): 2 steps
#   to Godric-Borrell: 2 steps
#   to Leona-Woolfield: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Patchface: 2 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Alliser-Thorne: 2 steps
#   to Azor-Ahai: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Donal-Noye: 2 steps
#   to Janos-Slynt: 2 steps
#   to Jon-Snow: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Clydas: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Val: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Dalla: 2 steps
#   to Sigorn: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Mance-Rayder: 2 steps
#   to Clayton-Suggs: 2 steps
#   to Godry-Farring: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Corliss-Penny: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Marya-Seaworth: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Satin: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Benethon-Scales: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Brus-Buckler: 2 steps
#   to Malegorn: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Gilly: 3 steps
#   to Rattleshirt: 3 steps
#   to Ygritte: 3 steps
#   to Alys-Karstark: 3 steps
#   to Hobb: 3 steps
#   to Joramun: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Gerald-Gower: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Gawen-Westerling: 3 steps
#   to Hother-Umber: 3 steps
#   to Chett: 3 steps
#   to Jeor-Mormont: 3 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Denys-Mallister: 3 steps
#   to Eddison-Tollett: 3 steps
#   to Grenn: 3 steps
#   to Owen: 3 steps
#   to Pypar: 3 steps
#   to Wynton-Stout: 3 steps
#   to Alleras: 3 steps
#   to Dareon: 3 steps
#   to Halder: 3 steps
#   to Rast: 3 steps
#   to Qhorin-Halfhand: 3 steps
#   to Othell-Yarwyck: 3 steps
#   to Mag-Mar-Tun-Doh-Weg: 3 steps
#   to Emmett: 3 steps
#   to Albett: 3 steps
#   to Dywen: 3 steps
#   to Jaremy-Rykker: 3 steps
#   to Matthar: 3 steps
#   to Othor: 3 steps
#   to Todder: 3 steps
#   to Craster: 3 steps
#   to Dalbridge: 3 steps
#   to Ebben: 3 steps
#   to Hake: 3 steps
#   to Jarman-Buckwell: 3 steps
#   to Lark: 3 steps
#   to Ottyn-Wythers: 3 steps
#   to Stonesnake: 3 steps
#   to Thoren-Smallwood: 3 steps
#   to Arson: 3 steps
#   to Big-Boil: 3 steps
#   to Dick-Follard: 3 steps
#   to Errok: 3 steps
#   to Gendel: 3 steps
#   to Gorne: 3 steps
#   to Grigg: 3 steps
#   to Hareth-(Moles-Town): 3 steps
#   to Harma: 3 steps
#   to Jarl: 3 steps
#   to Kegs: 3 steps
#   to Mully: 3 steps
#   to Orell: 3 steps
#   to Ryk: 3 steps
#   to Spare-Boot: 3 steps
#   to Styr: 3 steps
#   to Tormund: 3 steps
#   to Varamyr: 3 steps
#   to Zei: 3 steps
#   to Wick-Whittlestick: 3 steps
#   to Leathers: 3 steps
#   to Rory: 3 steps
#   to Soren-Shieldbreaker: 3 steps
#   to Tom-Barleycorn: 3 steps
#   to Toregg: 3 steps
#   to Ulmer: 3 steps
#   to Weeper: 3 steps
#   to Cellador: 3 steps
#   to Brandon-Norrey: 3 steps
#   to Hop-Robin: 3 steps
#   to Fulk: 3 steps
#   to Gerrick-Kingsblood: 3 steps
#   to Bannen: 3 steps
#   to Bedwyck: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Small-Paul: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Bael-the-Bard: 4 steps
#   to Blane: 4 steps
#   to Watt: 4 steps
#   to Armen: 4 steps
#   to Mollander: 4 steps
#   to Pate-(novice): 4 steps
#   to Roone: 4 steps
#   to Lanna-(Happy-Port): 4 steps
#   to Ragwyle: 4 steps
#   to Jafer-Flowers: 4 steps
#   to Byam-Flint: 4 steps
#   to Softfoot: 4 steps
#   to Mallador-Locke: 4 steps
#   to Munda: 4 steps
#   to Dryn: 4 steps
#   to Bump: 4 steps
#   to Haggon: 4 steps
#   to Thistle: 4 steps
#   to Torghen-Flint: 4 steps
#   to Raymun-Redbeard: 4 steps
#   to Walgrave: 5 steps
#   to Quill: 5 steps
#   to Rosey: 5 steps
#   to Gormon-Tyrell: 6 steps
# Shortest paths from node Godry-Farring:
#   to Godry-Farring: 0 steps
#   to Clayton-Suggs: 1 steps
#   to Jon-Snow: 1 steps
#   to Stannis-Baratheon: 1 steps
#   to Melisandre: 1 steps
#   to Mance-Rayder: 1 steps
#   to Aemon-Targaryen-(Maester-Aemon): 2 steps
#   to Albett: 2 steps
#   to Alliser-Thorne: 2 steps
#   to Bowen-Marsh: 2 steps
#   to Chett: 2 steps
#   to Dareon: 2 steps
#   to Donal-Noye: 2 steps
#   to Dywen: 2 steps
#   to Grenn: 2 steps
#   to Halder: 2 steps
#   to Hobb: 2 steps
#   to Jaremy-Rykker: 2 steps
#   to Jeor-Mormont: 2 steps
#   to Matthar: 2 steps
#   to Othor: 2 steps
#   to Pypar: 2 steps
#   to Rast: 2 steps
#   to Samwell-Tarly: 2 steps
#   to Todder: 2 steps
#   to Craster: 2 steps
#   to Dalbridge: 2 steps
#   to Ebben: 2 steps
#   to Eddison-Tollett: 2 steps
#   to Hake: 2 steps
#   to Jarman-Buckwell: 2 steps
#   to Lark: 2 steps
#   to Ottyn-Wythers: 2 steps
#   to Qhorin-Halfhand: 2 steps
#   to Rattleshirt: 2 steps
#   to Stonesnake: 2 steps
#   to Thoren-Smallwood: 2 steps
#   to Ygritte: 2 steps
#   to Arson: 2 steps
#   to Big-Boil: 2 steps
#   to Clydas: 2 steps
#   to Cotter-Pyke: 2 steps
#   to Dalla: 2 steps
#   to Dick-Follard: 2 steps
#   to Errok: 2 steps
#   to Gendel: 2 steps
#   to Gilly: 2 steps
#   to Gorne: 2 steps
#   to Grigg: 2 steps
#   to Hareth-(Moles-Town): 2 steps
#   to Harma: 2 steps
#   to Janos-Slynt: 2 steps
#   to Jarl: 2 steps
#   to Kegs: 2 steps
#   to Mag-Mar-Tun-Doh-Weg: 2 steps
#   to Mully: 2 steps
#   to Orell: 2 steps
#   to Owen: 2 steps
#   to Ryk: 2 steps
#   to Satin: 2 steps
#   to Spare-Boot: 2 steps
#   to Styr: 2 steps
#   to Tormund: 2 steps
#   to Val: 2 steps
#   to Varamyr: 2 steps
#   to Zei: 2 steps
#   to Sigorn: 2 steps
#   to Tycho-Nestoris: 2 steps
#   to Selyse-Florent: 2 steps
#   to Shireen-Baratheon: 2 steps
#   to Narbert-Grandison: 2 steps
#   to Othell-Yarwyck: 2 steps
#   to Wick-Whittlestick: 2 steps
#   to Malegorn: 2 steps
#   to Leathers: 2 steps
#   to Rory: 2 steps
#   to Patrek-of-Kings-Mountain: 2 steps
#   to Soren-Shieldbreaker: 2 steps
#   to Tom-Barleycorn: 2 steps
#   to Toregg: 2 steps
#   to Ulmer: 2 steps
#   to Weeper: 2 steps
#   to Wun-Weg-Wun-Dar-Wun: 2 steps
#   to Alys-Karstark: 2 steps
#   to Axell-Florent: 2 steps
#   to Cellador: 2 steps
#   to Brandon-Norrey: 2 steps
#   to Denys-Mallister: 2 steps
#   to Devan-Seaworth: 2 steps
#   to Emmett: 2 steps
#   to Hop-Robin: 2 steps
#   to Fulk: 2 steps
#   to Gerrick-Kingsblood: 2 steps
#   to Alester-Florent: 2 steps
#   to Allard-Seaworth: 2 steps
#   to Cortnay-Penrose: 2 steps
#   to Cressen: 2 steps
#   to Davos-Seaworth: 2 steps
#   to Monford-Velaryon: 2 steps
#   to Patchface: 2 steps
#   to Pylos: 2 steps
#   to Salladhor-Saan: 2 steps
#   to Azor-Ahai: 2 steps
#   to Edric-Storm: 2 steps
#   to Khorane-Sathmantes: 2 steps
#   to Wyman-Manderly: 2 steps
#   to Theomore: 2 steps
#   to William-Foxglove: 2 steps
#   to Arnolf-Karstark: 2 steps
#   to Mors-Umber: 2 steps
#   to Corliss-Penny: 2 steps
#   to Marlon-Manderly: 2 steps
#   to Lyanna-Mormont: 2 steps
#   to Marya-Seaworth: 2 steps
#   to Roose-Ryswell: 2 steps
#   to Guncer-Sunglass: 2 steps
#   to Joramun: 2 steps
#   to Aegon-V-Targaryen: 3 steps
#   to Daeron-II-Targaryen: 3 steps
#   to Maekar-I-Targaryen: 3 steps
#   to Wynton-Stout: 3 steps
#   to Alleras: 3 steps
#   to Small-Paul: 3 steps
#   to Lanna-(Happy-Port): 3 steps
#   to Bannen: 3 steps
#   to Bedwyck: 3 steps
#   to Jafer-Flowers: 3 steps
#   to Blane: 3 steps
#   to Clubfoot-Karl: 3 steps
#   to Dirk: 3 steps
#   to Xhondo: 3 steps
#   to Theobald: 3 steps
#   to Leo-Tyrell: 3 steps
#   to Marwyn: 3 steps
#   to Kojja-Mo: 3 steps
#   to Quhuru-Mo: 3 steps
#   to Byam-Flint: 3 steps
#   to Watt: 3 steps
#   to Softfoot: 3 steps
#   to Ragwyle: 3 steps
#   to Mallador-Locke: 3 steps
#   to Bael-the-Bard: 3 steps
#   to Arron: 3 steps
#   to Emrick: 3 steps
#   to Munda: 3 steps
#   to Dryn: 3 steps
#   to Bump: 3 steps
#   to Haggon: 3 steps
#   to Thistle: 3 steps
#   to Benethon-Scales: 3 steps
#   to Brus-Buckler: 3 steps
#   to Daeron-I-Targaryen: 3 steps
#   to Lamprey: 3 steps
#   to Porridge: 3 steps
#   to Torghen-Flint: 3 steps
#   to Raymun-Redbeard: 3 steps
#   to Imry-Florent: 3 steps
#   to Matthos-Seaworth: 3 steps
#   to Andrew-Estermont: 3 steps
#   to Bartimus: 3 steps
#   to Sybell-Spicer: 3 steps
#   to Garth-(Wolfs-Den): 3 steps
#   to Godric-Borrell: 3 steps
#   to Leona-Woolfield: 3 steps
#   to Ardrian-Celtigar: 3 steps
#   to Hother-Umber: 3 steps
#   to Arthor-Karstark: 3 steps
#   to Armen: 4 steps
#   to Mollander: 4 steps
#   to Pate-(novice): 4 steps
#   to Roone: 4 steps
#   to Gerald-Gower: 4 steps
#   to Gawen-Westerling: 4 steps
#   to Walgrave: 5 steps
#   to Quill: 5 steps
#   to Rosey: 5 steps
#   to Gormon-Tyrell: 6 steps

# %% [markdown]
# ## Calculate the Diameter (Longest Shortest Path)

# %%
# Get the instance of Neo4jConnection
db = neo4j.Neo4jConnection.get_instance()

# Load data into NetworkX
graph = db.load_data_into_networkx()

# Extract the largest community subgraph
largest_community_subgraph = db.subgraph_largest_community()

# Calculate all pairs shortest path lengths in the largest community subgraph
all_pairs_shortest_path_lengths = dict(nx.all_pairs_shortest_path_length(largest_community_subgraph))

# Initialize variables to store the longest shortest path and its length
longest_shortest_path = None
longest_shortest_path_length = 0

# Find the longest shortest path
for source, target_lengths in all_pairs_shortest_path_lengths.items():
    for target, length in target_lengths.items():
        if length > longest_shortest_path_length:
            longest_shortest_path_length = length
            longest_shortest_path = (source, target)

# Extract the nodes in the longest shortest path
if longest_shortest_path:
    source, target = longest_shortest_path
    longest_path_nodes = nx.shortest_path(largest_community_subgraph, source=source, target=target)
    print(f"Longest shortest path length: {longest_shortest_path_length}")
    print(f"Nodes in the longest shortest path: {longest_path_nodes}")
else:
    print("No paths found in the largest community subgraph")

# Close the Neo4j connection when done
db.close()
# Out:
# Longest shortest path length: 6
# Nodes in the longest shortest path: ['Gawen-Westerling', 'Sybell-Spicer', 'Wyman-Manderly', 'Stannis-Baratheon', 'Aemon-Targaryen-(Maester-Aemon)', 'Jeor-Mormont', 'Blane']

# %% [markdown]
# # Shortest Path from A to B

# %%
# Get the instance of Neo4jConnection
db = neo4j.Neo4jConnection.get_instance()

# Load data into NetworkX
graph = db.load_data_into_networkx()

# Extract the largest community subgraph
largest_community_subgraph = db.subgraph_largest_community()

# Define the start and end nodes (replace 'A' and 'B' with actual node identifiers)
start_node = 'Munda'
end_node = 'Gerald-Gower'

# Compute the shortest path from A to B
try:
    shortest_path = nx.shortest_path(largest_community_subgraph, source=start_node, target=end_node)
    shortest_path_length = nx.shortest_path_length(largest_community_subgraph, source=start_node, target=end_node)

    print(f"Shortest path from {start_node} to {end_node}: {shortest_path}")
    print(f"Shortest path length: {shortest_path_length} steps")
except nx.NetworkXNoPath:
    print(f"No path exists between {start_node} and {end_node}")

# Close the Neo4j connection when done
db.close()
# Out:
# Shortest path from Munda to Gerald-Gower: ['Munda', 'Tormund', 'Jon-Snow', 'Melisandre', 'Davos-Seaworth', 'Andrew-Estermont', 'Gerald-Gower']
# Shortest path length: 6 steps

# %% [markdown]
# # Task 4.1: What is the Shortest Path Between the Node with the Highest Closeness Centrality and 'Andrew-Estermont'
# Use what you have learned before to calculate the shortest path between the node with the highest closeness centrality and 'Andrew-Estermont'.

# %%
# Get the instance of Neo4jConnection
db = neo4j.Neo4jConnection.get_instance()

# Load data into NetworkX
graph = db.load_data_into_networkx()

# Extract the largest community subgraph
largest_community_subgraph = db.subgraph_largest_community()

# Calculate closeness centrality for all nodes
closeness_centrality = nx.closeness_centrality(largest_community_subgraph)

# Find the node with the highest closeness centrality
node_highest_closeness = max(closeness_centrality, key=closeness_centrality.get)

# Find the shortest path between the node with highest closeness centrality and 'Andrew-Estermont'
shortest_path = nx.shortest_path(largest_community_subgraph, source=node_highest_closeness, target='Andrew-Estermont')

# print result
print(f"Shortest path between {node_highest_closeness} and 'Andrew-Estermont': {shortest_path}")
# Out:
# Shortest path between Jon-Snow and 'Andrew-Estermont': ['Jon-Snow', 'Devan-Seaworth', 'Davos-Seaworth', 'Andrew-Estermont']
